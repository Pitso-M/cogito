# %%
#pip install langchain llama-index langchain_text_splitters llama-index-core

# %%
#to handle warning later on
import warnings
warnings.filterwarnings("ignore", message="Core Pydantic V1 functionality")
#to allow pretty printing of chunks
from pprint import pprint

# %%
text = "This facility is crude, but it should be adequate to freeze Skywalker for his journey to the Emperor. Vader lunges at him and Luke immediately raises his lit sword to meet Vader's.  Sparks fly as they duel, Vader gradually forcing Luke backward toward the gantry."
print(text)

# %% [markdown]
# Level 1: Character Splitting

# %%
#character splitting using simple slits at every chunk size
chunks = []
chunk_size = 25
#loop through the text and create chunks
for i in range(0, len(text), chunk_size):
    chunk = text[i:i+chunk_size]
    chunks.append(chunk)
print(chunks)

# %%
#character splitting using langchain - simple split
from langchain_text_splitters import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=25, chunk_overlap=0, separator=" ", strip_whitespace=True)
chunks = text_splitter.split_text(text)
print(chunks)

# %%
#chunking using langchain - create documents
from langchain_text_splitters import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=25, chunk_overlap=10, separator=' ', strip_whitespace=True)
chunks = text_splitter.create_documents([text])
print(chunks)

# %%
#splitting using llama index- default splitter is sentence splitter
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(chunk_size=25, chunk_overlap=10)
chunks = splitter.split_text(text)
pprint(chunks)

# %%
#splitting document and creating nodes using llama index
splitter = SentenceSplitter(chunk_size=100, chunk_overlap=10)

#load document
from llama_index.core import SimpleDirectoryReader
document = SimpleDirectoryReader(input_files=["./data_input/script_1.txt"]).load_data()
#create nodes
nodes = splitter.get_nodes_from_documents(document)
#nodes[0]
#pprint(nodes[0].__dict__)
pprint(nodes[1].model_dump())

# %% [markdown]
# Level 2: Recursive Character Text Splitting

# %%
#load longer text
with open("./data_input/long_text.txt", "r", encoding="utf-8") as f:
   long_text = f.read()
pprint(long_text)

# %%
#recursive text splitting via langchain
from langchain_text_splitters import RecursiveCharacterTextSplitter
#create text splitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=0)
text_splitter.create_documents([long_text])

# %%
#splitting using llama index- default splitter is sentence splitter - kinda equivalent to langchain recursive character splitter
from llama_index.core.node_parser import SentenceWindowNodeParser
#create text splitter
text_splitter = SentenceWindowNodeParser(chunk_size=150, chunk_overlap=0)
chunks = splitter.split_text(long_text)
pprint(chunks)

# %% [markdown]
# Level 3: Document Specific Splitting
# The Markdown, Python, and JS splitters will basically be similar to Recursive Character, but with different separators.

# %%
#markdown
#load markdown text
with open("./data_input/markdown_text.txt", "r", encoding="utf-8") as f:
   markdown_text = f.read()
print(markdown_text)
#create markdown text splitter and split text into documents
from langchain_text_splitters import MarkdownTextSplitter
text_splitter = MarkdownTextSplitter(chunk_size=150, chunk_overlap=0)
text_splitter.create_documents([markdown_text])

# %%
#python
#load python text
with open("./data_input/python_text.txt", "r", encoding="utf-8") as f:
   python_text = f.read()
print(python_text)
#create python text splitter and split text into documents
from langchain_text_splitters import PythonCodeTextSplitter
text_splitter = PythonCodeTextSplitter(chunk_size=150, chunk_overlap=0)
text_splitter.create_documents([python_text])

# %%
#javascript
#load js text
with open("./data_input/js_text.txt", "r", encoding="utf-8") as f:
   js_text = f.read()
print(js_text)
#create javascript text splitter using recursive character text splitter and language specification
from langchain_text_splitters import RecursiveCharacterTextSplitter, Language
text_splitter = RecursiveCharacterTextSplitter.from_language(language=Language.JS, chunk_size=150, chunk_overlap=0)
text_splitter.create_documents([js_text])

# %%
#pdfs with tables
#unstructured io
import os
from unstructured.partition.pdf import partition_pdf
from unstructured.staging.base import elements_to_json
#tesseract for ocr
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
#this method attempts to download a model from huggingface - won't work on vpn
pdf_file = "./data_input/pdf_form.pdf"
#extract pdf elements
pdf_elements = partition_pdf(filename = pdf_file, strategy='hi_res', infer_table_structure=True, model_name='yolox', languages=['eng'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured_pytesseract\pytesseract.py:275, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     274 try:
# --> 275     proc = subprocess.Popen(cmd_args, **subprocess_args())
#     276 except OSError as e:
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py:1038, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035             self.stderr = io.TextIOWrapper(self.stderr,
#    1036                     encoding=encoding, errors=errors)
# -> 1038     self._execute_child(args, executable, preexec_fn, close_fds,
#    1039                         pass_fds, cwd, env,
#    1040                         startupinfo, creationflags, shell,
#    1041                         p2cread, p2cwrite,
#    1042                         c2pread, c2pwrite,
#    1043                         errread, errwrite,
#    1044                         restore_signals,
#    1045                         gid, gids, uid, umask,
#    1046                         start_new_session, process_group)
#    1047 except:
#    1048     # Cleanup if the child failed starting.
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\subprocess.py:1552, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1551 try:
# -> 1552     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1553                              # no special security
#    1554                              None, None,
#    1555                              int(not close_fds),
#    1556                              creationflags,
#    1557                              env,
#    1558                              cwd,
#    1559                              startupinfo)
#    1560 finally:
#    1561     # Child is launched. Close the parent's copy of those pipe
#    1562     # handles that only the child should have open.  You need
#    (...)   1565     # pipe will not close when the child process exits and the
#    1566     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# TesseractNotFoundError                    Traceback (most recent call last)
# Cell In[16], line 4
#       2 pdf_file = "./data_input/pdf_form.pdf"
#       3 #extract pdf elements
# ----> 4 pdf_elements = partition_pdf(filename = pdf_file, strategy='hi_res', infer_table_structure=True, model_name='yolox', languages=['eng'])
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\common\metadata.py:161, in apply_metadata.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     159 @functools.wraps(func)
#     160 def wrapper(*args: _P.args, **kwargs: _P.kwargs) -> list[Element]:
# --> 161     elements = func(*args, **kwargs)
#     162     call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#     164     # ------------------------------------------------------------------------------------
#     165     # unique-ify elements
#     166     # ------------------------------------------------------------------------------------
#    (...)    171     # instance).
#     172     # ------------------------------------------------------------------------------------
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\chunking\dispatch.py:74, in add_chunking_strategy.<locals>.wrapper(*args, **kwargs)
#      71 """The decorated function is replaced with this one."""
#      73 # -- call the partitioning function to get the elements --
# ---> 74 elements = func(*args, **kwargs)
#      76 # -- look for a chunking-strategy argument --
#      77 call_args = get_call_args_applying_defaults(func, *args, **kwargs)
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\pdf.py:225, in partition_pdf(filename, file, include_page_breaks, strategy, infer_table_structure, ocr_languages, languages, detect_language_per_element, metadata_last_modified, chunking_strategy, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, starting_page_number, extract_forms, form_extraction_skip_tables, password, pdfminer_line_margin, pdfminer_char_margin, pdfminer_line_overlap, pdfminer_word_margin, **kwargs)
#     222 exactly_one(filename=filename, file=file)
#     224 languages = check_language_args(languages or [], ocr_languages)
# --> 225 return partition_pdf_or_image(
#     226     filename=filename,
#     227     file=file,
#     228     include_page_breaks=include_page_breaks,
#     229     strategy=strategy,
#     230     infer_table_structure=infer_table_structure,
#     231     languages=languages,
#     232     detect_language_per_element=detect_language_per_element,
#     233     metadata_last_modified=metadata_last_modified,
#     234     hi_res_model_name=hi_res_model_name,
#     235     extract_images_in_pdf=extract_images_in_pdf,
#     236     extract_image_block_types=extract_image_block_types,
#     237     extract_image_block_output_dir=extract_image_block_output_dir,
#     238     extract_image_block_to_payload=extract_image_block_to_payload,
#     239     starting_page_number=starting_page_number,
#     240     extract_forms=extract_forms,
#     241     form_extraction_skip_tables=form_extraction_skip_tables,
#     242     password=password,
#     243     pdfminer_line_margin=pdfminer_line_margin,
#     244     pdfminer_char_margin=pdfminer_char_margin,
#     245     pdfminer_line_overlap=pdfminer_line_overlap,
#     246     pdfminer_word_margin=pdfminer_word_margin,
#     247     **kwargs,
#     248 )
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\pdf.py:340, in partition_pdf_or_image(filename, file, is_image, include_page_breaks, strategy, infer_table_structure, languages, detect_language_per_element, metadata_last_modified, hi_res_model_name, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, starting_page_number, extract_forms, form_extraction_skip_tables, password, pdfminer_line_margin, pdfminer_char_margin, pdfminer_line_overlap, pdfminer_word_margin, ocr_agent, table_ocr_agent, **kwargs)
#     338 with warnings.catch_warnings():
#     339     warnings.simplefilter("ignore")
# --> 340     elements = _partition_pdf_or_image_local(
#     341         filename=filename,
#     342         file=spooled_to_bytes_io_if_needed(file),
#     343         is_image=is_image,
#     344         infer_table_structure=infer_table_structure,
#     345         include_page_breaks=include_page_breaks,
#     346         languages=languages,
#     347         ocr_languages=ocr_languages,
#     348         metadata_last_modified=metadata_last_modified or last_modified,
#     349         hi_res_model_name=hi_res_model_name,
#     350         pdf_text_extractable=pdf_text_extractable,
#     351         extract_images_in_pdf=extract_images_in_pdf,
#     352         extract_image_block_types=extract_image_block_types,
#     353         extract_image_block_output_dir=extract_image_block_output_dir,
#     354         extract_image_block_to_payload=extract_image_block_to_payload,
#     355         starting_page_number=starting_page_number,
#     356         extract_forms=extract_forms,
#     357         form_extraction_skip_tables=form_extraction_skip_tables,
#     358         password=password,
#     359         pdfminer_config=pdfminer_config,
#     360         ocr_agent=ocr_agent,
#     361         table_ocr_agent=table_ocr_agent,
#     362         **kwargs,
#     363     )
#     364     # NOTE(crag): do not call _process_uncategorized_text_elements here, because
#     365     # extracted elements (which are text blocks outside of OD-determined blocks)
#     366     # are likely not Titles and should not be identified as such.
#     367     return elements
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\utils.py:216, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     213 @wraps(func)
#     214 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     215     run_check()
# --> 216     return func(*args, **kwargs)
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\pdf.py:691, in _partition_pdf_or_image_local(filename, file, is_image, infer_table_structure, include_page_breaks, languages, ocr_languages, ocr_mode, model_name, hi_res_model_name, pdf_image_dpi, metadata_last_modified, pdf_text_extractable, extract_images_in_pdf, extract_image_block_types, extract_image_block_output_dir, extract_image_block_to_payload, analysis, analyzed_image_output_dir_path, starting_page_number, extract_forms, form_extraction_skip_tables, pdf_hi_res_max_pages, password, pdfminer_config, ocr_agent, table_ocr_agent, **kwargs)
#     684     # NOTE(christine): merged_document_layout = extracted_layout + inferred_layout
#     685     merged_document_layout = merge_inferred_with_extracted_layout(
#     686         inferred_document_layout=inferred_document_layout,
#     687         extracted_layout=extracted_layout,
#     688         hi_res_model_name=hi_res_model_name,
#     689     )
# --> 691     final_document_layout = process_file_with_ocr(
#     692         filename,
#     693         merged_document_layout,
#     694         extracted_layout=extracted_layout,
#     695         is_image=is_image,
#     696         infer_table_structure=infer_table_structure,
#     697         ocr_agent=ocr_agent,
#     698         ocr_languages=ocr_languages,
#     699         ocr_mode=ocr_mode,
#     700         pdf_image_dpi=pdf_image_dpi,
#     701         ocr_layout_dumper=ocr_layout_dumper,
#     702         password=password,
#     703         table_ocr_agent=table_ocr_agent,
#     704     )
#     705 else:
#     706     inferred_document_layout = process_data_with_model(
#     707         file,
#     708         is_image=is_image,
#    (...)    711         password=password,
#     712     )
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\utils.py:216, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     213 @wraps(func)
#     214 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     215     run_check()
# --> 216     return func(*args, **kwargs)
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\pdf_image\ocr.py:200, in process_file_with_ocr(filename, out_layout, extracted_layout, is_image, infer_table_structure, ocr_agent, ocr_languages, ocr_mode, pdf_image_dpi, ocr_layout_dumper, password, table_ocr_agent)
#     198 except Exception as e:
#     199     if os.path.isdir(filename) or os.path.isfile(filename):
# --> 200         raise e
#     201     else:
#     202         raise FileNotFoundError(f'File "{filename}" not found!') from e
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\pdf_image\ocr.py:185, in process_file_with_ocr(filename, out_layout, extracted_layout, is_image, infer_table_structure, ocr_agent, ocr_languages, ocr_mode, pdf_image_dpi, ocr_layout_dumper, password, table_ocr_agent)
#     183     extracted_regions = extracted_layout[i] if i < len(extracted_layout) else None
#     184     with PILImage.open(image_path) as image:
# --> 185         merged_page_layout = supplement_page_layout_with_ocr(
#     186             page_layout=out_layout.pages[i],
#     187             image=image,
#     188             infer_table_structure=infer_table_structure,
#     189             ocr_agent=ocr_agent,
#     190             ocr_languages=ocr_languages,
#     191             ocr_mode=ocr_mode,
#     192             extracted_regions=extracted_regions,
#     193             ocr_layout_dumper=ocr_layout_dumper,
#     194             table_ocr_agent=table_ocr_agent,
#     195         )
#     196         merged_page_layouts.append(merged_page_layout)
#     197 return DocumentLayout.from_pages(merged_page_layouts)
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\utils.py:216, in requires_dependencies.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     213 @wraps(func)
#     214 def wrapper(*args: _P.args, **kwargs: _P.kwargs):
#     215     run_check()
# --> 216     return func(*args, **kwargs)
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\pdf_image\ocr.py:230, in supplement_page_layout_with_ocr(page_layout, image, infer_table_structure, ocr_agent, ocr_languages, ocr_mode, extracted_regions, ocr_layout_dumper, table_ocr_agent)
#     228 _ocr_agent = OCRAgent.get_instance(ocr_agent_module=ocr_agent, language=language)
#     229 if ocr_mode == OCRMode.FULL_PAGE.value:
# --> 230     ocr_layout = _ocr_agent.get_layout_from_image(image)
#     231     if ocr_layout_dumper:
#     232         ocr_layout_dumper.add_ocred_page(ocr_layout.as_list())
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\utils\ocr_models\tesseract_ocr.py:55, in OCRAgentTesseract.get_layout_from_image(self, image)
#      53 trace_logger.detail("Processing entire page OCR with tesseract...")
#      54 zoom = 1
# ---> 55 ocr_df: pd.DataFrame = self.image_to_data_with_character_confidence_filter(
#      56     np.array(image),
#      57     lang=self.language,
#      58     character_confidence_threshold=env_config.TESSERACT_CHARACTER_CONFIDENCE_THRESHOLD,
#      59 )
#      60 ocr_df = ocr_df.dropna()
#      62 # tesseract performance degrades when the text height is out of the preferred zone so we
#      63 # zoom the image (in or out depending on estimated text height) for optimum OCR results
#      64 # but this needs to be evaluated based on actual use case as the optimum scaling also
#      65 # depend on type of characters (font, language, etc); be careful about this
#      66 # functionality
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured\partition\utils\ocr_models\tesseract_ocr.py:101, in OCRAgentTesseract.image_to_data_with_character_confidence_filter(self, image, lang, config, character_confidence_threshold)
#      94 def image_to_data_with_character_confidence_filter(
#      95     self,
#      96     image: np.ndarray,
#    (...)     99     character_confidence_threshold: float = 0.0,
#     100 ) -> pd.DataFrame:
# --> 101     hocr: str = unstructured_pytesseract.image_to_pdf_or_hocr(
#     102         image,
#     103         lang=lang,
#     104         config="-c hocr_char_boxes=1 " + config,
#     105         extension="hocr",
#     106     )
#     107     ocr_df = self.hocr_to_dataframe(hocr, character_confidence_threshold)
#     108     return ocr_df
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured_pytesseract\pytesseract.py:514, in image_to_pdf_or_hocr(image, lang, config, nice, extension, timeout)
#     510     config = f'-c tessedit_create_hocr=1 {config.strip()}'
#     512 args = [image, extension, lang, config, nice, timeout, True]
# --> 514 return run_and_get_output(*args)
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured_pytesseract\pytesseract.py:353, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     342 with save(image) as (temp_name, input_filename):
#     343     kwargs = {
#     344         'input_filename': input_filename,
#     345         'output_filename_base': temp_name,
#    (...)    350         'timeout': timeout,
#     351     }
# --> 353     run_tesseract(**kwargs)
#     354     return _read_output(
#     355         f"{kwargs['output_filename_base']}{extsep}{extension}",
#     356         return_bytes,
#     357     )
#
# File c:\Users\x464364\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\unstructured_pytesseract\pytesseract.py:280, in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     278         raise
#     279     else:
# --> 280         raise TesseractNotFoundError()
#     282 with timeout_manager(proc, timeout) as error_string:
#     283     if proc.returncode:
#
# TesseractNotFoundError: tesseract is not installed or it's not in your PATH. See README file for more information.

# %%
#this method attempts to download is simpler and runs locally
pdf_file = "./data_input/pdf_form.pdf"
#extract pdf elements
pdf_elements = partition_pdf(filename = pdf_file, strategy='fast', infer_table_structure=True, languages=['eng'])
pdf_elements

# %%
pdf_elements[0].metadata.text_as_html

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
print(pytesseract.get_tesseract_version())

# %%
import subprocess
result = subprocess.run(["choco", "list"], capture_output=True, text=True)
print(result.stdout)
# Out:
# Chocolatey v2.3.0
# 3 validations performed. 2 success(es), 1 warning(s), and 0 error(s).
#
# Validation Warnings:
#  - A pending system reboot request has been detected, however, this is
#    being ignored due to the current command 'list' being used.
#    It is recommended that you reboot at your earliest convenience.
#
# chocolatey 2.3.0
# chocolatey-compatibility.extension 1.0.0
# chocolatey-core.extension 1.4.0
# chocolatey-windowsupdate.extension 1.0.5
# KB2919355 1.0.20160915
# KB2919442 1.0.20160915
# KB2999226 1.0.20181019
# KB3033929 1.0.5
# KB3035131 1.0.3
# python314 3.14.3
# speedtest 1.2.0
# tesseract 5.5.0.20241111
# vcredist140 14.50.35719
# vcredist2015 14.0.24215.20170201
# 14 packages installed.
#
# Did you know Pro / Business automatically syncs with Programs and
#  Features? Learn more about Package Synchronizer at
#  https://chocolatey.org/compare
