# %%
#test for choco installations and version
import subprocess
result = subprocess.run(["choco", "list"], capture_output=True, text=True)
print(result.stdout)
